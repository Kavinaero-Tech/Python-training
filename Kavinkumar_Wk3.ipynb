# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavinaero-Tech/Python-training/blob/main/Kavinkumar_Wk3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Conditional Printing

# %%
number = 7
if number % 2 == 0:
  print(number, "is even.")
else:
  print(number, "is odd.")
# Out:
# 7 is odd.

# %% [markdown]
# 2.User Input and Age Check (with Modification)

# %%
age = int(input("Enter your age: "))
if age >= 18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote yet.")
# Out:
# Enter your age: 40
# You are eligible to vote.

# %% [markdown]
# Answer: used user define function()

# %%
def checkEligibility(a):
       if age >= 18:
        return True
       else:
        return False

age = int(input("Enter Age : "))

result = checkEligibility(age)

if result:
    print("Yes! You're eligible for voting")
else:
    print("No! You're not eligible for voting")
# Out:
# Enter Age : 17
# No! You're not eligible for voting

# %% [markdown]
# 3. Accessing Elements in Lists

# %%
fruits = ["apple", "banana", "orange"]
second_fruit = fruits[1]
print(second_fruit)
# Out:
# banana

# %% [markdown]
# Answer: Thus, 0 and 1 are the indices of the elements ‘apples’ and ‘banana’ respectively.
# Indexing in a python list starts from 0. This means that,
# Index of 1st element= 0
# Index of 2nd element= 1
# Index of 3rd element= 2
# .
# .
# .
# Index of nth element= n-1

# %%
fruits = ["apple", "banana", "orange"]
print(fruits[-1])
# Out:
# orange

# %% [markdown]
# 4. Looping in Reverse

# %%
for i in range(5, 0, -1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Answer:This code uses a Python for loop with index in conjunction with the range() function to generate a sequence of numbers starting from 5, up to (but not including) 0, and with a step size of -1. For each number in the sequence, the loop prints its value using the print() function. The output will show the numbers 5, 4, 3, 2, and 1.

# %% [markdown]
# 5. Lists vs. Tuples

# %%
# List (can be modified)
my_list = [1, 2, 3]
my_list[0] = 10  # Modifying an element

# Tuple (immutable)
my_tuple = (1, 2, 3)
# my_tuple[0] = 10  # This will cause an error!

# %% [markdown]
# Answer:
#   List: Lists are mutable, which means you can modify, add, or remove elements after the list is created. You can use methods like append(), extend(), insert(), remove(), and pop() to modify a list.
#
#   Tuple: Tuples are immutable. Once a tuple is created, you cannot change its elements. You cannot add, remove, or modify elements in a tuple.

# %%
my_list = [1, 2, 3]
my_list[0] = 10
print(my_list)
# Out:
# [10, 2, 3]

# %%
 # Converting a Tuple to a List
numbers = (1, 2, 3, 4, 5)
numbers = list(numbers)
numbers[0] = 10
numbers = tuple(numbers)
print(numbers) # Output: (10, 2, 3, 4, 5)
# Out:
# (10, 2, 3, 4, 5)

# %%
my_list = [1, 2.4, 'a string', ['a string in another list', 5]]

my_list[1]
# Out:
# 2.4

# %%
my_list = [1, 2.4, 'a string', ['a sting in another list', 5]]
my_tuple = tuple(my_list)
my_tuple
# Out:
# (1, 2.4, 'a string', ['a sting in another list', 5])

# %% [markdown]
# We can also create a tuple by doing a type conversion. We can convert our list to a tuple.Note that the list within my_list did not get converted to a tuple. It is still a list, and it is mutable.

# %%
my_tuple[3][0] = 'a string in a list in a tuple'
my_tuple
# Out:
# (1, 2.4, 'a string', ['a string in a list in a tuple', 5])

# %%
nested_tuple = (1,2,3,(4,5,6),7,8)
print(nested_tuple)
# Out:
# (1, 2, 3, (4, 5, 6), 7, 8)

# %% [markdown]
# if we try to change an item in a tuple, we get an error.

# %%
my_tuple[1] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-9a5ea503b98a> in <cell line: 1>()
# ----> 1 my_tuple[1] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 6. Understanding input()

# %%
name = input("What is your name? ")
print("Hello,", name + "!")
# Out:
# What is your name? k 6.0
# Hello, k 6.0!

# %% [markdown]
# Answer: input() function to take input from the user. Whatever you enter as input, the input function converts it into a string. If you enter an integer value still input() function converts it into a string.

# %% [markdown]
# 7. Simple Calculator (with Extension)

# %%
# Taking input
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')

# Addition
sum = float(num1) + float(num2)
# Subtraction
min = float(num1) - float(num2)
# Multiplication
mul = float(num1) * float(num2)
#Division
div = float(num1) / float(num2)
#Modulus
mod = float(num1) % float(num2)
#Exponentiation
exp = float(num1) ** float(num2)
# Floor Division
floordiv = float(num1) // float(num2)


print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
print('The subtraction of {0} and {1} is {2}'.format(num1, num2, min))
print('The multiplication of {0} and {1} is {2}'.format(num1, num2, mul))
print('The division of {0} and {1} is {2}'.format(num1, num2, div))
print('The modulus of {0} and {1} is {2}'.format(num1, num2, mod))
print('The exponentiation of {0} and {1} is {2}'.format(num1, num2, exp))
print('The floor division between {0} and {1} is {2}'.format(num1, num2,floordiv))
# Out:
# Enter first number: 2
# Enter second number: 3
# The sum of 2 and 3 is 5.0
# The subtraction of 2 and 3 is -1.0
# The multiplication of 2 and 3 is 6.0
# The division of 2 and 3 is 0.6666666666666666
# The modulus of 2 and 3 is 2.0
# The exponentiation of 2 and 3 is 8.0
# The floor division between 2 and 3 is 0.0

# %% [markdown]
# Modify this program to allow the user to choose the operation (+, -, *, /) they want to perform.

# %%
# Function to perform the arithmetic operation: Addition
def add(number_1, number_2):
    return number_1 + number_2

# Function to perform the arithmetic operation: Subtraction
def subtract(number_1, number_2):
    return number_1 - number_2

# Function to perform the arithmetic operation: Multiplication
def multiply(number_1, number_2):
    return number_1 * number_2

# Function to perform the arithmetic operation: Division
def divide(number_1, number_2):
    return number_1 / number_2

print("Hi, I am a Calculator!")
print("Please select which of the following arithematic operation you want me to perform-\n" \
        "1. Add\n" \
        "2. Subtract\n" \
        "3. Multiply\n" \
        "4. Divide\n")

# Taking the input from the user for which arithmetic operation to perform
operation = int(input(" 1, 2, 3 or 4 :"))

number_1 = int(input('Please, Enter the first number: '))
number_2 = int(input('Please, Enter the second number: '))

if operation == 1:
    print(number_1, "+", number_2, "=",
                    add(number_1, number_2))

elif operation == 2:
    print(number_1, "-", number_2, "=",
                    subtract(number_1, number_2))

elif operation == 3:
    print(number_1, "*", number_2, "=",
                    multiply(number_1, number_2))

elif operation == 4:
    print(number_1, "/", number_2, "=",
                    divide(number_1, number_2))
else:
    print("Please enter Valid input")
# Out:
# Hi, I am a Calculator!
# Please select which of the following arithematic operation you want me to perform-
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
#
#  1, 2, 3 or 4 :1
# Please, Enter the first number: 2
# Please, Enter the second number: 3
# 2 + 3 = 5

# %% [markdown]
# 8. String Concatenation (with f-strings)

# %%
first_name = "Alice"
greeting = "Hello, " + first_name + "!"
print(greeting)
# Out:
# Hello, Alice!

# %% [markdown]
# Formatted string literals or f-strings, in short, are string literals in Python. They contain an f at the beginning and curly braces that contain the expressions. It calls the str() method when an object argument is used as field replacement.

# %%
a = "Hello"
b = "Alice"
print(f'{a} {b}!')
# Out:
# Hello Alice!

# %% [markdown]
# 9. Indentation and its Role

# %%
if True:
  print("This line is indented, so it will be executed.")
print("This line is not indented, so it might cause an error.")
# Out:
# This line is indented, so it will be executed.
# This line is not indented, so it might cause an error.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In Python, indentation is used to determine the scope of statements within a block. Incorrect indentation can lead to syntax errors or logical errors in the code. Therefore, it is essential to follow the indentation rules to ensure the code runs smoothly.

# %% [markdown]
# 10. Mad Libs Fun (with Expansion)

# %%
adjective = input("Enter an adjective: ")
noun = input("Enter a noun: ")
verb = input("Enter a verb: ")

story = "The " + adjective + " " + noun + " " + verb + "!"
print(story)
# Out:
# Enter an adjective: dog
# Enter a noun: is
# Enter a verb: beautiful
# The dog is beautiful!

# %% [markdown]
# 10.Expand this code to create a more complex Mad Libs story with multiple prompts for different words.

# %% [markdown]
# The objective of this code is to develop a Mad Libs Generator (Mad Libs is a phrasal template word) python project. In this python code, the user first has to pick a story by the words for the story. Then the user has to enter specific words like a noun, verb, adjective, etc, according to the requirements. And then the story will be generated.
